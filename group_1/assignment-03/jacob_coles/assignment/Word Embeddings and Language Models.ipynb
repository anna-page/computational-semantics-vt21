# %% [markdown]
# # Lab 3: Word Embeddings and Language Modelling
#
# Adam Ek

# %% [markdown]
# In this lab we'll explore constructing *static* word embeddings (i.e. word2vec) and building language models. We'll also evaluate these systems on intermediate tasks, namely word similarity and identifying "good" and "bad" sentences.
#
# * For this we'll use pytorch. Some basic operations that will be useful can be found here: https://jhui.github.io/2018/02/09/PyTorch-Basic-operations
# * In general: we are not interested in getting state-of-the-art performance :) focus on the implementation and not results of your model. For this reason, you can use a subset of the dataset: the first 5000-10 000 sentences or so, on linux/mac: ```head -n 10000 inputfile > outputfile```.
# * If possible, use the MLTGpu, it will make everything faster :)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchtext.legacy.data import Field, BucketIterator, Iterator, TabularDataset
import pandas as pd
from torch.nn import CrossEntropyLoss


# for gpu, replace "cpu" with "cuda:n" where n is the index of the GPU
device = torch.device('cpu')

# %% [markdown]
# # Word2Vec embeddings
#
# In this first part we'll construct a word2vec model which will give us *static* word embeddings (that is, they are fixed after training).
#
# After we've trained our model we will evaluate the embeddings obtained on a word similarity task.

# %% [markdown]
# ## Formatting data

# %% [markdown]
# First we need to load some data, you can download the file on canvas under files/03-lab-data/wiki-corpus.txt. The file contains 50 000 sentences randomly selected from the complete wikipedia. Each line in the file contains one sentence. The sentences are whitespace tokenized.
#
# Your first task is to create a dataset suitable for word2vec. That is, we define some ```window_size``` then iterate over all sentences in the dataset, putting the center word in one field and the context words in another (separate the fields with ```tab```).
#
# For example, the sentece "this is a lab" with ```window size = 4``` will be formatted as:
# ```
# center, context
# ---------------------
# this    is a
# is      this a lab
# a       this is lab
# lab     is a
# ```
#
# this will be our training examples when training the word2vec model.
#
# [3 marks]

# %%
import re
data_path = 'wiki-corpus-5000.txt'
def corpus_reader(data_path, WINDOW_SIZE = 4):
    doc = "target\tcontext\n"
    with open(data_path) as f:
        for line in f:
            line = re.sub('\t', ' ', line)
            line = re.sub(r'"', '½', line)
            line = re.sub('\n\n', '\n', line)
            line_split = line.strip('\n').split(' ')
            word_w_context = str()
            for word_index in range(len(line_split)):
                doc += ( line_split[word_index] + '\t' )
                
                for i in range(word_index - int(WINDOW_SIZE/2), word_index + int(WINDOW_SIZE/2)):
                    if (not ((i<0) or (i>len(line_split)-1))) and not i==word_index:
                        doc += ( line_split[i] + ' ' )
                
                doc += '\n'
    
    doc = re.sub(' \n', '\n', doc)

    doc = re.sub(r'"', '½', doc)
    
    with open("output.csv", "w") as f:
        f.write(doc)
        
corpus_reader(data_path)

# %% [markdown]
# We sampled 50 000 senteces completely random from the *whole* wikipedia for our training data. Give some reasons why this is good, and why it might be bad. (*note*: We'll have a few questions like these, one or two reasons for and against is sufficient)
#
# [2 marks]

# %% [markdown]
# ### Loading the data
#
# We now need to load the data in an appropriate format for torchtext (https://torchtext.readthedocs.io/en/latest/). We'll use PyText for this and it'll follow the same structure as I showed you in the lecture (remember to lower-case all tokens). Create a function which returns a (bucket)iterator of the training data, and the vocabulary object (```Field```).
#
# (*hint1*: you can format the data such that the center word always is first, then you only need to use one field)
#
# (*hint2*: the code I showed you during the leture is available in /files/pytorch_tutorial/ on canvas)
#
# [4 marks]

# %%
def get_data():
    whitespacer = lambda x: x.split(' ')
    ddir = './training_data.csv'

    # "fields" that process the different columns in our CSV files
    TARGET = Field(lower       = True,
                   batch_first = True) # enforce the (batch, words) structure

    CONTEXT = Field(tokenize    = whitespacer,
                    lower       = True,
                    batch_first = True)

    # read the csv files
    dataset = TabularDataset(path   = ddir,
                                        format = 'csv',
                                        fields = [('target', TARGET),
                                                  ('context', TARGET)],
                                        skip_header       = True,
                                        csv_reader_params = {'delimiter':'\t',
                                                             'quotechar':'½'})

    # build vocabularies based on what our csv files contained and create word2id mapping
    TARGET.build_vocab(dataset)

    # create batches from our data, and shuffle them for each epoch
    dataset_iter = BucketIterator(dataset,
                                    batch_size        = 64,
                                    sort_within_batch = True,
                                    sort_key          = lambda x: len(x.target),
                                    shuffle           = True,
                                    device            = device)

    return dataset_iter, TARGET #train_iter, test_iter, TOKENS, LABELS

# %% [markdown]
# We lower-cased all tokens above; give some reasons why this is a good idea, and why it may be harmful to our embeddings.
#
# [2 marks]

# %%
dataset, TARGET = get_data()

# %% [markdown]
# ## Word Embeddings Model

# %% [markdown]
# We will implement the CBOW model for constructing word embedding models.

# %%
import torch.optim as optim

# %% [markdown]
# In the CBOW model we try to predict the center word based on the context. That is, we take as input ```n``` context words, encode them as vectors, then combine them by summation. This will give us one embedding. We then use this embedding to predict *which* word in our vocabuary is the most likely center word.
#
# Implement this model
#
# [7 marks]

# %%
class CBOWModel(nn.Module):
    def __init__(self, vocab_len, embedding_dim):
        super(CBOWModel, self).__init__()
        self.embeddings = nn.Embedding(vocab_len, embedding_dim)
        self.prediction = nn.Linear(embedding_dim, vocab_len) 
    
    def forward(self, context):
        #embed the words in our context
        # First look up the embeddings for all the words in the documents.
        # The shape is now (max_len, n_docs, emb_dim).
        embedded_context = self.embeddings(context)
        
        # Compute the mean of word embeddings over the documents.
        # The shape is now (n_docs, emb_dim)
        projection = self.projection_function(embedded_context)
        
        # Finally, compute the output word.
        predictions = self.prediction(projection)
        
        return predictions
        
    def projection_function(self, xs):
        """
        This function will take as input a tensor of size (B, S, D)
        where B is the batch_size, S the window size, and D the dimensionality of embeddings
        this function should compute the sum over the embedding dimensions of the input, 
        that is, we transform (B, S, D) to (B, 1, D) or (B, D) 
        """
        xs_sum = torch.sum(xs,1)
        return xs_sum

# %% [markdown]
# Now we need to train the models. First we define which hyperparameters to use. (You can change these, for example when *developing* your model you can use a batch size of 2 and a very low dimensionality (say 10), just to speed things up). When actually training your model *fo real*, you can use a batch size of [8,16,32,64], and embedding dimensionality of [128,256].

# %%
# you can change these numbers to suit your needs :)
word_embeddings_hyperparameters = {'epochs':1,
                                   'batch_size':64,
                                   'embedding_size':128,
                                   'learning_rate':0.001,
                                   'embedding_dim':128}

# %% [markdown]
# Train your model. Iterate over the dataset, get outputs from your model, calculate loss and backpropagate.
#
# We mentioned in the lecture that we use Negative Log Likelihood (https://pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html) loss to train Word2Vec model. In this lab we'll take a shortcut when *training* and use Cross Entropy Loss (https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html), basically it combines ```log_softmax``` and ```NLLLoss```. So what your model should output is a *score* for each word in our vocabulary. The ```CrossEntropyLoss``` will then assign probabilities and calculate the negative log likelihood loss.
#
# [3 marks]

# %%
# load data
dataset, vocab = get_data()

vocab_len = len(vocab.vocab)

# build model and construct loss/optimizer
cbow_model = CBOWModel(vocab_len, word_embeddings_hyperparameters['embedding_dim'])
cbow_model.to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(cbow_model.parameters(), lr=word_embeddings_hyperparameters['learning_rate'])

# start training loop
total_loss = 0
for epoch in range(word_embeddings_hyperparameters['epochs']):
    for i, batch in enumerate(dataset):
        
        context = batch.context
        target_word = batch.target
        
        # send your batch of sentences to the model
        output = cbow_model(context)
        
        # compute the loss, you'll need to reshape the input
        # you can read more about this is the documentation for
        # CrossEntropyLoss
        loss = loss_fn(output.view(-1,vocab_len), target_word.view(-1))
        total_loss += loss.item()
        
        # print average loss for the epoch
        print(total_loss/(i+1), end='\r') 
        
        # compute gradients
        loss.backward()
        
        # update parameters
        optimizer.step()
        
        # reset gradients
        optimizer.zero_grad()
    print()
# Out:
# 7.9633558442079915

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# We will evaluate the model on a dataset of word similarities, WordSim353 (http://alfonseca.org/eng/research/wordsim353.html , also avalable in vanvas under files/03-l). The first thing we need to do is read the dataset and translate it to integers. What we'll do is to reuse the ```Field``` that records word indexes (the second output of ```get_data()```) and use it to parse the file.
#
# The wordsim data is structured as follows:
#
# ```
# word1 word2 score
# ...
# ```
#
#
# The ```Field``` we got from ```read_data()``` has two built-in functions, ```stoi``` which maps a string to an integer and ```itos``` which maps an integer to a string.
#
# What our datareader needs to do is:
#
# ```
# for line in file:
#     word1, word2, score = file.split()
#     # encode word1 and word2 as integers
#     word1_idx = vocab.vocab.stoi[word1]
#     word2_idx = vocab.vocab.stoi[word2]
# ```
#
# when we have the integers for ```word_1``` and ```word2``` we'll compute the similarity between their word embeddings with *cosine simlarity*. We can obtain the embeddings by querying the embedding layer of the model.
#
# We calculate the cosine similarity for each word pair in the dataset, then compute the pearson correlation between the similarities we obtained with the scores given in the dataset.
#
# [4 marks]

# %%
# your code goes here

def read_wordsim(path, vocab, embeddings):
    dataset_sims = []
    model_sims = []
    words = []
    with open(path) as f:
        for line in f:
            word1, word2, score = line.split()
            
            score = float(score)
            dataset_sims.append(score)
            words.append((word1,word2))
            
            # get the index for the word
            word1_idx = vocab.vocab.stoi[word1]
            word2_idx = vocab.vocab.stoi[word2]
            
            # get the embedding of the word
            word1_emb = embeddings(torch.tensor([word1_idx]))
            word2_emb = embeddings(torch.tensor([word2_idx]))
            
            # compute cosine similarity, we'll use the version included in pytorch functional
            # https://pytorch.org/docs/master/generated/torch.nn.functional.cosine_similarity.html
            cosine_similarity = F.cosine_similarity(word1_emb, word2_emb)
            
            model_sims.append(cosine_similarity.item())
    
    return dataset_sims, model_sims, words

path = 'wordsim_similarity_goldstandard.txt'
data, model, words = read_wordsim(path,vocab,cbow_model.embeddings)
pearson_correlation = np.corrcoef(data, model)
            
# the non-diagonals give the pearson correlation,
print(pearson_correlation)


for i in range(len(words)):
    print(words[i]," data score: ",data[i]," model score: ",(model[i]+1)*5)
# Out:
# [[1.         0.26579159]
#  [0.26579159 1.        ]]
# ('tiger', 'cat')  data score:  7.35  model score:  5.422746986150742
# ('tiger', 'tiger')  data score:  10.0  model score:  10.0
# ('plane', 'car')  data score:  5.77  model score:  5.103033520281315
# ('train', 'car')  data score:  6.31  model score:  4.5652661100029945
# ('television', 'radio')  data score:  6.77  model score:  5.038661938160658
# ('media', 'radio')  data score:  7.42  model score:  5.382809229195118
# ('bread', 'butter')  data score:  6.19  model score:  5.373343415558338
# ('cucumber', 'potato')  data score:  5.92  model score:  5.208325162529945
# ('doctor', 'nurse')  data score:  7.0  model score:  4.828064497560263
# ('professor', 'doctor')  data score:  6.62  model score:  4.25451472401619
# ('student', 'professor')  data score:  6.81  model score:  5.129983965307474
# ('smart', 'stupid')  data score:  5.81  model score:  10.0
# ('wood', 'forest')  data score:  7.73  model score:  5.052444045431912
# ('money', 'cash')  data score:  9.15  model score:  5.147902267053723
# ('king', 'queen')  data score:  8.58  model score:  5.416671261191368
# ('king', 'rook')  data score:  5.92  model score:  4.604882709681988
# ('bishop', 'rabbi')  data score:  6.69  model score:  5.273517873138189
# ('fuck', 'sex')  data score:  9.44  model score:  5.191840101033449
# ('football', 'soccer')  data score:  9.03  model score:  4.2903802543878555
# ('football', 'basketball')  data score:  6.81  model score:  4.70087381079793
# ('football', 'tennis')  data score:  6.63  model score:  4.583992399275303
# ('Arafat', 'Jackson')  data score:  2.5  model score:  10.0
# ('physics', 'chemistry')  data score:  7.35  model score:  6.046919152140617
# ('vodka', 'gin')  data score:  8.46  model score:  10.0
# ('vodka', 'brandy')  data score:  8.13  model score:  10.0
# ('drink', 'eat')  data score:  6.87  model score:  5.483368970453739
# ('car', 'automobile')  data score:  8.94  model score:  4.961078250780702
# ('gem', 'jewel')  data score:  8.96  model score:  10.0
# ('journey', 'voyage')  data score:  9.29  model score:  5.63592441380024
# ('boy', 'lad')  data score:  8.83  model score:  4.622417092323303
# ('coast', 'shore')  data score:  9.1  model score:  4.858265668153763
# ('asylum', 'madhouse')  data score:  8.87  model score:  10.0
# ('magician', 'wizard')  data score:  9.02  model score:  10.0
# ('midday', 'noon')  data score:  9.29  model score:  10.0
# ('furnace', 'stove')  data score:  8.79  model score:  5.596879385411739
# ('food', 'fruit')  data score:  7.52  model score:  5.615235045552254
# ('bird', 'cock')  data score:  7.1  model score:  5.142288580536842
# ('bird', 'crane')  data score:  7.38  model score:  4.460599012672901
# ('food', 'rooster')  data score:  4.42  model score:  4.8747924249619246
# ('money', 'dollar')  data score:  8.42  model score:  4.655423983931541
# ('money', 'currency')  data score:  9.04  model score:  5.4358502477407455
# ('tiger', 'jaguar')  data score:  8.0  model score:  10.0
# ('tiger', 'feline')  data score:  8.0  model score:  10.0
# ('tiger', 'carnivore')  data score:  7.08  model score:  10.0
# ('tiger', 'mammal')  data score:  6.85  model score:  5.303412321954966
# ('tiger', 'animal')  data score:  7.0  model score:  4.661615155637264
# ('tiger', 'organism')  data score:  4.77  model score:  4.280433729290962
# ('tiger', 'fauna')  data score:  5.62  model score:  10.0
# ('psychology', 'psychiatry')  data score:  8.08  model score:  4.317236095666885
# ('psychology', 'science')  data score:  6.71  model score:  5.234890840947628
# ('psychology', 'discipline')  data score:  5.58  model score:  4.8238941095769405
# ('planet', 'star')  data score:  8.45  model score:  5.0196042796596885
# ('planet', 'moon')  data score:  8.08  model score:  5.454482845962048
# ('planet', 'sun')  data score:  8.02  model score:  5.243268925696611
# ('precedent', 'example')  data score:  5.85  model score:  4.820149876177311
# ('precedent', 'antecedent')  data score:  6.04  model score:  5.189636666327715
# ('cup', 'tableware')  data score:  6.85  model score:  5.816918238997459
# ('cup', 'artifact')  data score:  2.92  model score:  5.594725161790848
# ('cup', 'object')  data score:  3.69  model score:  5.120016895234585
# ('cup', 'entity')  data score:  2.15  model score:  4.269626289606094
# ('jaguar', 'cat')  data score:  7.42  model score:  5.422746986150742
# ('jaguar', 'car')  data score:  7.27  model score:  5.26136951521039
# ('mile', 'kilometer')  data score:  8.66  model score:  4.464287608861923
# ('skin', 'eye')  data score:  6.22  model score:  4.7538915276527405
# ('Japanese', 'American')  data score:  6.5  model score:  10.0
# ('century', 'year')  data score:  7.59  model score:  4.74754711613059
# ('announcement', 'news')  data score:  7.56  model score:  4.840470254421234
# ('doctor', 'personnel')  data score:  5.0  model score:  5.212536845356226
# ('Harvard', 'Yale')  data score:  8.13  model score:  10.0
# ('hospital', 'infrastructure')  data score:  4.63  model score:  4.2475710809230804
# ('life', 'death')  data score:  7.88  model score:  4.806914832442999
# ('travel', 'activity')  data score:  5.0  model score:  4.811035841703415
# ('type', 'kind')  data score:  8.97  model score:  5.014047202421352
# ('street', 'place')  data score:  6.44  model score:  5.542912036180496
# ('street', 'avenue')  data score:  8.88  model score:  5.11887033469975
# ('street', 'block')  data score:  6.88  model score:  4.815685246139765
# ('cell', 'phone')  data score:  7.81  model score:  4.674263894557953
# ('dividend', 'payment')  data score:  7.63  model score:  5.743682309985161
# ('calculation', 'computation')  data score:  8.44  model score:  4.7139194048941135
# ('profit', 'loss')  data score:  7.63  model score:  4.709484111517668
# ('dollar', 'yen')  data score:  7.78  model score:  4.488278664648533
# ('dollar', 'buck')  data score:  9.22  model score:  4.488278664648533
# ('phone', 'equipment')  data score:  7.13  model score:  4.933647834695876
# ('liquid', 'water')  data score:  7.89  model score:  5.645720884203911
# ('marathon', 'sprint')  data score:  7.47  model score:  10.0
# ('seafood', 'food')  data score:  8.34  model score:  4.7458332777023315
# ('seafood', 'lobster')  data score:  8.7  model score:  4.7826761938631535
# ('lobster', 'food')  data score:  7.81  model score:  4.8747924249619246
# ('lobster', 'wine')  data score:  5.7  model score:  5.943538099527359
# ('championship', 'tournament')  data score:  8.36  model score:  4.945611911825836
# ('man', 'woman')  data score:  8.3  model score:  5.043741464614868
# ('man', 'governor')  data score:  5.25  model score:  5.425339564681053
# ('murder', 'manslaughter')  data score:  8.53  model score:  4.920134823769331
# ('opera', 'performance')  data score:  6.88  model score:  5.036381061654538
# ('Mexico', 'Brazil')  data score:  7.44  model score:  10.0
# ('glass', 'metal')  data score:  5.56  model score:  5.018226153915748
# ('aluminum', 'metal')  data score:  7.83  model score:  5.193049218505621
# ('rock', 'jazz')  data score:  7.59  model score:  5.234418902546167
# ('museum', 'theater')  data score:  7.19  model score:  5.7511186599731445
# ('shower', 'thunderstorm')  data score:  6.31  model score:  4.7984992899000645
# ('monk', 'oracle')  data score:  5.0  model score:  5.045245587825775
# ('cup', 'food')  data score:  5.0  model score:  5.9697820991277695
# ('journal', 'association')  data score:  4.97  model score:  5.672621354460716
# ('street', 'children')  data score:  4.94  model score:  5.269182901829481
# ('car', 'flight')  data score:  4.94  model score:  5.570060350000858
# ('space', 'chemistry')  data score:  4.88  model score:  4.621613882482052
# ('situation', 'conclusion')  data score:  4.81  model score:  3.982083946466446
# ('word', 'similarity')  data score:  4.75  model score:  5.052120485343039
# ('peace', 'plan')  data score:  4.75  model score:  4.828404448926449
# ('consumer', 'energy')  data score:  4.75  model score:  4.111948907375336
# ('ministry', 'culture')  data score:  4.69  model score:  4.623144157230854
# ('smart', 'student')  data score:  4.62  model score:  5.155906677246094
# ('investigation', 'effort')  data score:  4.59  model score:  5.465341992676258
# ('image', 'surface')  data score:  4.56  model score:  5.368940196931362
# ('life', 'term')  data score:  4.5  model score:  4.8320879228413105
# ('start', 'match')  data score:  4.47  model score:  5.765340402722359
# ('computer', 'news')  data score:  4.47  model score:  5.403905287384987
# ('board', 'recommendation')  data score:  4.47  model score:  5.43869249522686
# ('lad', 'brother')  data score:  4.46  model score:  5.886467173695564
# ('observation', 'architecture')  data score:  4.38  model score:  5.044766026549041
# ('coast', 'hill')  data score:  4.38  model score:  5.32740693539381
# ('deployment', 'departure')  data score:  4.25  model score:  5.239508990198374
# ('benchmark', 'index')  data score:  4.25  model score:  5.77903039753437
# ('attempt', 'peace')  data score:  4.25  model score:  5.249862112104893
# ('consumer', 'confidence')  data score:  4.13  model score:  5.211136247962713
# ('start', 'year')  data score:  4.06  model score:  5.619844309985638
# ('focus', 'life')  data score:  4.06  model score:  4.385064393281937
# ('development', 'issue')  data score:  3.97  model score:  5.753306001424789
# ('theater', 'history')  data score:  3.91  model score:  5.171248614788055
# ('situation', 'isolation')  data score:  3.88  model score:  4.686591103672981
# ('profit', 'warning')  data score:  3.88  model score:  5.099506191909313
# ('media', 'trading')  data score:  3.88  model score:  5.297252424061298
# ('chance', 'credibility')  data score:  3.88  model score:  5.273801703006029
# ('precedent', 'information')  data score:  3.85  model score:  4.505224674940109
# ('architecture', 'century')  data score:  3.78  model score:  5.591242648661137
# ('population', 'development')  data score:  3.75  model score:  5.02074878429994
# ('stock', 'live')  data score:  3.73  model score:  4.492384605109692
# ('peace', 'atmosphere')  data score:  3.69  model score:  5.277609881013632
# ('morality', 'marriage')  data score:  3.69  model score:  4.750098288059235
# ('minority', 'peace')  data score:  3.69  model score:  5.047798017039895
# ('atmosphere', 'landscape')  data score:  3.69  model score:  4.761260710656643
# ('report', 'gain')  data score:  3.63  model score:  4.402699135243893
# ('music', 'project')  data score:  3.63  model score:  5.59774212539196
# ('seven', 'series')  data score:  3.56  model score:  5.310668982565403
# ('experience', 'music')  data score:  3.47  model score:  5.738030299544334
# ('school', 'center')  data score:  3.44  model score:  4.4090573862195015
# ('five', 'month')  data score:  3.38  model score:  3.9120418578386307
# ('announcement', 'production')  data score:  3.38  model score:  4.784041903913021
# ('morality', 'importance')  data score:  3.31  model score:  4.601348973810673
# ('money', 'operation')  data score:  3.31  model score:  5.59250358492136
# ('delay', 'news')  data score:  3.31  model score:  5.2387684397399426
# ('governor', 'interview')  data score:  3.25  model score:  4.750713109970093
# ('practice', 'institution')  data score:  3.19  model score:  4.538569189608097
# ('century', 'nation')  data score:  3.16  model score:  5.050116321071982
# ('coast', 'forest')  data score:  3.15  model score:  4.904023194685578
# ('shore', 'woodland')  data score:  3.08  model score:  5.511477664113045
# ('drink', 'car')  data score:  3.04  model score:  5.019186126301065
# ('president', 'medal')  data score:  3.0  model score:  5.084129199385643
# ('prejudice', 'recognition')  data score:  3.0  model score:  5.082692140713334
# ('viewer', 'serial')  data score:  2.97  model score:  5.254465565085411
# ('peace', 'insurance')  data score:  2.94  model score:  4.857630375772715
# ('Mars', 'water')  data score:  2.94  model score:  5.41078295558691
# ('media', 'gain')  data score:  2.88  model score:  5.271539390087128
# ('precedent', 'cognition')  data score:  2.81  model score:  5.617365352809429
# ('announcement', 'effort')  data score:  2.75  model score:  4.753484893590212
# ('line', 'insurance')  data score:  2.69  model score:  4.621603675186634
# ('crane', 'implement')  data score:  2.69  model score:  4.903212673962116
# ('drink', 'mother')  data score:  2.65  model score:  4.64844673871994
# ('opera', 'industry')  data score:  2.63  model score:  4.838266000151634
# ('volunteer', 'motto')  data score:  2.56  model score:  5.16028355807066
# ('listing', 'proximity')  data score:  2.56  model score:  4.967513487208635
# ('precedent', 'collection')  data score:  2.5  model score:  5.227572750300169
# ('cup', 'article')  data score:  2.4  model score:  4.334663897752762
# ('sign', 'recess')  data score:  2.38  model score:  5.703495964407921
# ('problem', 'airport')  data score:  2.38  model score:  4.56453163176775
# ('reason', 'hypertension')  data score:  2.31  model score:  4.884499749168754
# ('direction', 'combination')  data score:  2.25  model score:  5.045486590825021
# ('Wednesday', 'news')  data score:  2.22  model score:  4.682416990399361
# ('glass', 'magician')  data score:  2.08  model score:  4.867621986195445
# ('cemetery', 'woodland')  data score:  2.08  model score:  5.504105053842068
# ('possibility', 'girl')  data score:  1.94  model score:  4.8385267704725266
# ('cup', 'substance')  data score:  1.92  model score:  4.985136545728892
# ('forest', 'graveyard')  data score:  1.85  model score:  5.756878107786179
# ('stock', 'egg')  data score:  1.81  model score:  4.737642649561167
# ('month', 'hotel')  data score:  1.81  model score:  5.6976353377103806
# ('energy', 'secretary')  data score:  1.81  model score:  4.222583845257759
# ('precedent', 'group')  data score:  1.77  model score:  4.895474063232541
# ('production', 'hike')  data score:  1.75  model score:  5.179216451942921
# ('stock', 'phone')  data score:  1.62  model score:  5.463325344026089
# ('holy', 'sex')  data score:  1.62  model score:  4.846478858962655
# ('stock', 'CD')  data score:  1.31  model score:  5.305576175451279
# ('drink', 'ear')  data score:  1.31  model score:  5.151655878871679
# ('delay', 'racism')  data score:  1.19  model score:  4.741843827068806
# ('stock', 'life')  data score:  0.92  model score:  4.884148230776191
# ('stock', 'jaguar')  data score:  0.92  model score:  5.305576175451279
# ('monk', 'slave')  data score:  0.92  model score:  5.137070883065462
# ('lad', 'wizard')  data score:  0.92  model score:  10.0
# ('sugar', 'approach')  data score:  0.88  model score:  4.756554402410984
# ('rooster', 'voyage')  data score:  0.62  model score:  4.5114971324801445
# ('noon', 'string')  data score:  0.54  model score:  5.180027857422829
# ('chord', 'smile')  data score:  0.54  model score:  4.2576634138822556
# ('professor', 'cucumber')  data score:  0.31  model score:  4.717413019388914
# ('king', 'cabbage')  data score:  0.23  model score:  4.604882709681988

# %% [markdown]
# Do you think the model performs good or bad? Why?
#
# [3 marks]

# %% [markdown]
# Select the 10 best and 10 worst performing word pairs, can you see any patterns that explain why *these* are the best and worst word pairs?
#
# [3 marks]

# %% [markdown]
# Suggest some ways of improving the model we apply to WordSim353.
#
# [3 marks]

# %% [markdown]
# If we consider a scenario where we use these embeddings in a downstream task, for example sentiment analysis (roughly: determining whether a sentence is positive or negative).
#
# Give some examples why the sentiment analysis model would benefit from our embeddnings and one examples why our embeddings could hur the performance of the sentiment model.
#
# [3 marks]

# %% [markdown]
# # Language modeling

# %% [markdown]
# In this second part we'll build a simple LSTM language model. Your task is to construct a model which takes a sentence as input and predict the next word for each word in the sentence. For this you'll use the ```LSTM``` class provided by PyTorch (https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html). You can read more about the LSTM here: https://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# NOTE!!!: Use the same dataset (wiki-cropus.txt) as before.
#
# Our setup is similar to before, we first encode the words as distributed representations then pass these to the LSTM and for each output we predict the next word.
#
# For this we'll build a new dataloader with torchtext, the file we pass to the dataloader should contain one sentence per line, with words separated by whitespace.
#
# ```
# word_1, ..., word_n
# word_1, ..., word_k
# ...
# ```
#
# in this dataloader you want to make sure that each sentence begins with a ```<start>``` token and ends with a ```<end>``` token, there is a keyword argument in ```Field``` for this :). But other than that, as before you read the dataset and output a iterator over the dataset and a vocabulary.
#
# Implement the dataloader, language model and the training loop (the training loop will basically be the same as for word2vec).
#
# [12 marks]

# %%
# you can change these numbers to suit your needs as before :)
lm_hyperparameters = {'epochs':3,
                      'batch_size':16,
                      'learning_rate':0.001,
                      'embedding_dim':128,
                      'output_dim':128}

# %%
data_path = 'wiki-corpus-5000.txt'
def get_data():
    whitespacer = lambda x: x.split(' ')
    ddir = data_path

    # "fields" that process the different columns in our CSV files
    SENTENCE = Field(init_token = "<start>",
                   eos_token = "<end>",
                   lower       = True,
                   batch_first = True) # enforce the (batch, words) structure


    # read the csv files
    dataset = TabularDataset(path   = ddir,
                                        format = 'csv',
                                        fields = [('sentence', SENTENCE)],
                                        skip_header       = True,
                                        csv_reader_params = {'delimiter':'\t',
                                                             'quotechar':'½'})

    # build vocabularies based on what our csv files contained and create word2id mapping
    SENTENCE.build_vocab(dataset)

    # create batches from our data, and shuffle them for each epoch
    dataset_iter = BucketIterator(dataset,
                                    batch_size        = 64,
                                    sort_within_batch = True,
                                    sort_key          = lambda x: len(x.sentence),
                                    shuffle           = True,
                                    device            = device)

    return dataset_iter, SENTENCE

# %%
class LM_withLSTM(nn.Module):
    def __init__(self, vocab_len, embedding_dim, output_dim):
        super(LM_withLSTM, self).__init__()
        self.embeddings = nn.Embedding(vocab_len, embedding_dim)
        #self.prediction = nn.Linear(embedding_dim, vocab_len) 
        self.LSTM = nn.LSTM(input_size=embedding_dim,
                            hidden_size=output_dim)
        self.predict_word = nn.Linear(output_dim, vocab_len)

    
    def forward(self, seq):
        embedded_seq = self.embeddings(seq)
        timestep_reprentation, *_ = self.LSTM(embedded_seq) #.view(len(seq),-1,1)
        predicted_words = self.predict_word(timestep_reprentation) #.view(len(seq),-1)
        
        return predicted_words

# %%
# load data
dataset, vocab = get_data()

# build model and construct loss/optimizer
lm_model = LM_withLSTM(len(vocab.vocab), 
                       lm_hyperparameters['embedding_dim'],
                       lm_hyperparameters['output_dim'])
lm_model.to(device)

loss_fn = CrossEntropyLoss()
optimizer = optim.Adam(cbow_model.parameters(), lr=lm_hyperparameters['learning_rate'])

# start training loop
total_loss = 0
for epoch in range(lm_hyperparameters['epochs']):
    for i, batch in enumerate(dataset):
        
        # the strucure for each BATCH is:
        # <start>, w0, ..., wn, <end>
        sentence = batch.sentence
        
        # when training the model, at each input we predict the *NEXT* token
        # consequently there is nothing to predict when we give the model 
        # <end> as input. 
        # thus, we do not want to give <end> as input to the model, select 
        # from each batch all tokens except the last. 
        # tip: use pytorch indexing/slicing (same as numpy) 
        # (https://pytorch.org/tutorials/beginner/basics/tensorqs_tutorial.html#operations-on-tensors)
        # (https://jhui.github.io/2018/02/09/PyTorch-Basic-operations/)

        input_sentence = sentence[:-1]
        
        # send your batch of sentences to the model
        output = lm_model(input_sentence)
        
        # for each output, the model predict the NEXT token, so we have to reshape 
        # our dataset again. On timestep t, we evaluate on token t+1. That is,
        # we never predict the <start> token ;) so this time, we select all but the first 
        # token from sentences (that is, all the tokens that we predict)
        gold_data = [sentence[i+1] for i in range(len(input_sentence))][:-1]
        
        # the shape of the output and sentence variable need to be changed,
        # for the loss function. Details are in the documentation.
        # You can use .view(...,...) to reshape the tensors  
        loss = loss_fn(output.view(-1,len(vocab.vocab)), gold_data)
        total_loss += loss.item()
        
        # print average loss for the epoch
        print(total_loss/(i+1), end='\r') 
        
        # compute gradients
        loss.backward()
        
        # update parameters
        optimizer.step()
        
        # reset gradients
        optimizer.zero_grad()
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-93d7814bbebd> in <module>
#      38         # we never predict the <start> token ;) so this time, we select all but the first
#      39         # token from sentences (that is, all the tokens that we predict)
# ---> 40         gold_data = torch.Tensor([sentence[i+1] for i in range(len(input_sentence))][:-1])
#      41         print(gold_data)
#      42         # the shape of the output and sentence variable need to be changed,
#
# ValueError: only one element tensors can be converted to Python scalars

# %% [markdown]
# ### Evaluating the language model
#
# We'll evaluate our model using the BLiMP dataset (https://github.com/alexwarstadt/blimp). The BLiMP dataset contains sets of linguistic minimal pairs for various syntactic and semantic phenomena, We'll evaluate our model on *existential quantifiers* (link: https://github.com/alexwarstadt/blimp/blob/master/data/existential_there_quantifiers_1.jsonl). This data, as the name suggests, investigate whether language models assign higher probability to *correct* usage of there-quantifiers.
#
# An example entry in the dataset is:
#
# ```
# {"sentence_good": "There was a documentary about music irritating Allison.", "sentence_bad": "There was each documentary about music irritating Allison.", "field": "semantics", "linguistics_term": "quantifiers", "UID": "existential_there_quantifiers_1", "simple_LM_method": true, "one_prefix_method": false, "two_prefix_method": false, "lexically_identical": false, "pairID": "0"}
# ```
#
# Download the dataset and build a datareader (similar to what you did for word2vec). The dataset structure you should aim for is (you don't need to worry about the other keys for this assignment):
#
# ```
# good_sentence_1, bad_sentence_1
# ...
# ```
#
# your task now is to compare the probability assigned to the good sentence with to the probability assigned to the bad sentence. To compute a probability for a sentence we consider the product of the probabilities assigned to the *gold* tokens, remember, at timestep ```t``` we're predicting which token comes *next* e.g. ```t+1``` (basically, you do the same thing as you did when training).
#
# In rough pseudo code what your code should do is:
#
# ```
# accuracy = []
# for good_sentence, bad_sentence in dataset:
#     gs_lm_output = LanguageModel(good_sentence)
#     gs_token_probabilities = softmax(gs_lm_output)
#     gs_sentence_probability = product(gs_token_probabilities[GOLD_TOKENS])
#
#     bs_lm_output = LanguageModel(bad_sentence)
#     bs_token_probabilities = softmax(bs_lm_output)
#     bs_sentence_probability = product(bs_token_probabilities[GOLD_TOKENS])
#
#     # int(True) = 1 and int(False) = 0
#     is_correct = int(gs_sentence_probability > bs_sentence_probability)
#     accuracy.append(is_correct)
#
# print(numpy.mean(accuracy))
#
# ```
#
# [6 marks]

# %%
# your code goes here
import json

def evaluate_model(path, vocab, model):
    
    accuracy = []
    with open(path) as f:
        # iterate over one pair of sentences at a time
        for line in f:
            # load the data
            data = json.loads(line)
            good_s = data['sentence_good']
            bad_s = data['sentence_bad']
            
            # the data is tokenized as whitespace
            tok_good_s = ...
            tok_bad_s = ...
            
            # encode your words as integers using the vocab from the dataloader, size is (S)
            # we use unsqueeze to create the batch dimension 
            # in this case our input is only ONE batch, so the size of the tensor becomes: 
            # (S) -> (1, S) as the model expects batches
            enc_good_s = torch.tensor([_ for x in tok_good_s], device=device).unsqueeze(0)
            enc_bad_s = torch.tensor([_ for x in tok_bad_s], device=device).unsqueeze(0)
            
            # pass your encoded sentences to the model and predict the next tokens
            good_s = LM_withLSTM(enc_good_s)
            bad_s = LM_withLSTM(enc_bad_s)
            
            # get probabilities with softmax
            gs_probs = F.softmax(...)
            bs_probs = F.softmax(...)
            
            # select the probability of the gold tokens
            gs_sent_prob = find_token_probs(gs_probs, enc_good_s)
            bs_sent_prob = find_token_probs(bs_probs, enc_bad_s)
            
            accuracy.append(int(gs_sent_prob>bs_sent_prob))
            
    return accuracy
            
def find_token_probs(model_probs, encoded_sentece):
    probs = []

    # iterate over the tokens in your encoded sentence
    for token, gold_token in enumerate(encoded_sentece):
        # select the probability of the gold tokens and save
        # hint: pytorch indexing is helpful here ;)
        prob = ...
        probs.append(prob)
    sentence_prob = ...
    return sentence_prob

path = 'existential_there_quantifiers_1.jsonl'
accuracy = evaluate_model(path, ..., ...)

print('Final accuracy:')
print(np.round(np.mean(accuracy), 3))

# %% [markdown]
# ### Analysis

# %% [markdown]
# Our model get some score, say, 55% correct predictions. Is this good? Suggest some *baseline* (i.e. a stupid "model" we hope ours is better than) we can compare the model against.
#
# [3 marks]

# %% [markdown]
# Suggest some improvements you could make to your language model.
#
# [3 marks]

# %% [markdown]
# Suggest some other metrics we can use to evaluate our system
#
# [2 marks]

# %%
"Anarchist historian ".split(' ')
# Out:
# ['Anarchist', 'historian', '']

# %% [markdown]
# # Literature
#
#
# Neural architectures:
# * Y. Bengio, R. Ducharme, P. Vincent, and C. Janvin. A neural probabilistic language model. (Links to an external site.) Journal of Machine Learning Research, 3(6):1137–1155, 2003. (Sections 3 and 4 are less relevant today and hence you can glance through them quickly. Instead, look at the Mikolov papers where they describe training word embeddings with the current neural network architectures.)
# * T. Mikolov, K. Chen, G. Corrado, and J. Dean. Efficient estimation of word representations in vector space. arXiv preprint arXiv:1301.3781, 2013.
# * T. Mikolov, I. Sutskever, K. Chen, G. S. Corrado, and J. Dean. Distributed representations of words and phrases and their compositionality. In Advances in neural information processing systems, pages 3111–3119, 2013.

# %% [markdown]
# Total marks: 63
